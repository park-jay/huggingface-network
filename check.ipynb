# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/jaipark/Library/CloudStorage/OneDrive-IndianaUniversity/repository/data/huggingface/anuska/huggingface_models.csv')

# %%
df.shape
# Out:
# (913375, 6)

# %%
df.head(5)
# Out:
#                  task  creator            model_name  \
# 0  image-text-to-text     Qwen       Qwen3.5-35B-A3B
# 1  image-text-to-text     Qwen           Qwen3.5-27B
# 2  image-text-to-text  unsloth  Qwen3.5-35B-A3B-GGUF
# 3  image-text-to-text     Qwen     Qwen3.5-122B-A10B
# 4  image-text-to-text     Qwen     Qwen3.5-397B-A17B
#
#                                                  url  \
# 0        https://huggingface.co/Qwen/Qwen3.5-35B-A3B
# 1            https://huggingface.co/Qwen/Qwen3.5-27B
# 2  https://huggingface.co/unsloth/Qwen3.5-35B-A3B...
# 3      https://huggingface.co/Qwen/Qwen3.5-122B-A10B
# 4      https://huggingface.co/Qwen/Qwen3.5-397B-A17B
#
#                                           model_card  image_count
# 0  # Qwen3.5-35B-A3B [](https://chat.qwen.ai) > [...            1
# 1  # Qwen3.5-27B [](https://chat.qwen.ai) > [!Not...            1
# 2  To run Qwen3.5 locally - Read our Guide! Unslo...            2
# ...
